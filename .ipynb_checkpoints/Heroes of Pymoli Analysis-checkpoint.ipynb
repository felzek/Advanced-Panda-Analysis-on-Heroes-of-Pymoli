# %% [markdown]
# <h2><a href="#option-1-heroes-of-pymoli" aria-hidden="true" class="anchor" id="user-content-option-1-heroes-of-pymoli"><svg aria-hidden="true" class="octicon octicon-link" height="16" version="1.1" viewBox="0 0 16 16" width="16"><path fill-rule="evenodd" d="M4 9h1v1H4c-1.5 0-3-1.69-3-3.5S2.55 3 4 3h4c1.45 0 3 1.69 3 3.5 0 1.41-.91 2.72-2 3.25V8.59c.58-.45 1-1.27 1-2.09C10 5.22 8.98 4 8 4H4c-.98 0-2 1.22-2 2.5S3 9 4 9zm9-3h-1v1h1c1 0 2 1.22 2 2.5S13.98 12 13 12H9c-.98 0-2-1.22-2-2.5 0-.83.42-1.64 1-2.09V6.25c-1.09.53-2 1.84-2 3.25C6 11.31 7.55 13 9 13h4c1.45 0 3-1.69 3-3.5S14.5 6 13 6z"></path></svg></a>Heroes of Pymoli</h2>
# <div><img src="https://github.com/the-Coding-Boot-Camp-at-UT/UTAAU201710DATA1-Class-Repository-DATA/raw/master/1-Class-Content/04-Pandas/Homework/Instructions/Images/Fantasy.jpg" alt="Fantasy" style="max-width:100%;"><img src="https://media0.giphy.com/media/1wh06XT53tPGw/giphy.gif"></img></div>
# <p>Congratulations! After a lot of hard work in the data munging mines, you've landed a job as Lead Analyst for an independent gaming company. You've been assigned the task of analyzing the data for their most recent fantasy game Heroes of Pymoli.</p>
# <p>Like many others in its genre, the game is free-to-play, but players are encouraged to purchase optional items that enhance their playing experience. As a first task, the company would like you to generate a report that breaks down the game's purchasing data into meaningful insights.</p>
# <p>Your final report should include each of the following:</p>
# <p><strong>Player Count</strong></p>
# <ul>
# <li>Total Number of Players</li>
# </ul>
# <p><strong>Purchasing Analysis (Total)</strong></p>
# <ul>
# <li>Number of Unique Items</li>
# <li>Average Purchase Price</li>
# <li>Total Number of Purchases</li>
# <li>Total Revenue</li>
# </ul>
# <p><strong>Gender Demographics</strong></p>
# <ul>
# <li>Percentage and Count of Male Players</li>
# <li>Percentage and Count of Female Players</li>
# <li>Percentage and Count of Other / Non-Disclosed</li>
# </ul>
# <p><strong>Purchasing Analysis (Gender)</strong></p>
# <ul>
# <li>The below each broken by gender
# <ul>
# <li>Purchase Count</li>
# <li>Average Purchase Price</li>
# <li>Total Purchase Value</li>
# <li>Normalized Totals</li>
# </ul>
# </li>
# </ul>
# <p><strong>Age Demographics</strong></p>
# <ul>
# <li>The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.)
# <ul>
# <li>Purchase Count</li>
# <li>Average Purchase Price</li>
# <li>Total Purchase Value</li>
# <li>Normalized Totals</li>
# </ul>
# </li>
# </ul>
# <p><strong>Top Spenders</strong></p>
# <ul>
# <li>Identify the the top 5 spenders in the game by total purchase value, then list (in a table):
# <ul>
# <li>SN</li>
# <li>Purchase Count</li>
# <li>Average Purchase Price</li>
# <li>Total Purchase Value</li>
# </ul>
# </li>
# </ul>
# <p><strong>Most Popular Items</strong></p>
# <ul>
# <li>Identify the 5 most popular items by purchase count, then list (in a table):
# <ul>
# <li>Item ID</li>
# <li>Item Name</li>
# <li>Purchase Count</li>
# <li>Item Price</li>
# <li>Total Purchase Value</li>
# </ul>
# </li>
# </ul>
# <p><strong>Most Profitable Items</strong></p>
# <ul>
# <li>Identify the 5 most profitable items by total purchase value, then list (in a table):
# <ul>
# <li>Item ID</li>
# <li>Item Name</li>
# <li>Purchase Count</li>
# <li>Item Price</li>
# <li>Total Purchase Value</li><img src="data:image/png;base64,..." width ="25px"></img>
# </ul>
# </li>
# </ul>
# <p>As final considerations:</p>
# <ul>
# <li>Your script must work for both data-sets given.</li>
# <li>You must use the Pandas Library and the Jupyter Notebook.</li>
# <li>You must submit a link to your Jupyter Notebook with the viewable Data Frames.</li>
# <li>You must include an exported markdown version of your Notebook called  <code>README.md</code> in your GitHub repository.</li>
# <li>You must include a written description of three observable trends based on the data.</li>
# <li>See <a href="/the-Coding-Boot-Camp-at-UT/UTAAU201710DATA1-Class-Repository-DATA/blob/master/1-Class-Content/04-Pandas/Homework/Instructions/HeroesOfPymoli/HeroesOfPymoli_Example.pdf">Example Solution</a> for a reference on expected format.</li>
# </ul>

# %% [markdown]
# <p><img src="https://media1.giphy.com/media/jZBSmF6TM7Udi/giphy.gif" width ="300px;"><img></p>
# <img src="data:image/png;base64,..." width ="25px"></img>

# %%
import pandas as pd
import numpy as ny 
import os



datasource = os.path.join("Source_data","purchase_data.json")
datasource_2 = os.path.join("Source_data","purchase_data2.json")

purchase_data_df= pd.read_json(datasource)
purchase_data_df_2 = pd.read_json(datasource_2)


merged_data_dfa = pd.merge(purchase_data_df,purchase_data_df_2, on = ["Age","Gender","Item ID","Item Name","Price","SN"], how ="outer" )
merged_data_df = merged_data_dfa.drop_duplicates()

# %%
total_players = merged_data_df["SN"].nunique()
total_players_df = pd.DataFrame({"Total Players":[total_players]})
total_players_df.head()
# Out:
#    Total Players
# 0            612

# %% [markdown]
# <h1 style="font-size:100;font-weight:600;">Purchasing Analysis</h1>

# %% [markdown]
# z## Player Count
# purchase_data_df.columns

# %%
num_unique_items = merged_data_df["Item ID"].nunique()
average_purchase_price = merged_data_df["Price"].mean()
total_number_of_purchases= merged_data_df["Item ID"].count()
total_revenue = merged_data_df["Price"].sum()

purchasing_analysis = pd.DataFrame({"Number of Unique Items":[num_unique_items],
                                    "Average Price":[average_purchase_price],
                                    "Number of Purchases":[total_number_of_purchases],
                                    "Total Revenue":"$" + str(round(total_revenue,2)) })
purchasing_analysis
# Out:
#    Average Price  Number of Purchases  Number of Unique Items Total Revenue
# 0       2.932655                  855                     184      $2507.42

# %% [markdown]
# <h1 style="font-size:100;font-weight:600;">Gender Demographics</h1>

# %%
total_gender = merged_data_df["Gender"].count()
male = merged_data_df["Gender"].value_counts()["Male"]
female = merged_data_df["Gender"].value_counts()["Female"]
non_gender = total_gender - male - female

percentage_male_count = male / total_gender * 100
percentage_female_count = female / total_gender * 100
percentage_nonspecific_count = non_gender / total_gender * 100

gender_demographics_df = pd.DataFrame({"Male": [male,percentage_male_count] ,
                                       "Female":[female,percentage_female_count],
                                       "Non-Specific":[non_gender,percentage_nonspecific_count]
                                       
                                      
                                      },index = ["Count","Percentage of Players"])
gender_demographics_df.transpose()
# Out:
#               Count  Percentage of Players
# Female        148.0              17.309942
# Male          695.0              81.286550
# Non-Specific   12.0               1.403509

# %% [markdown]
# <h1 style="font-size:100;font-weight:600;">Purchasing Analysis (Gender)</h1>

# %%
male_purchase = merged_data_df.loc[merged_data_df["Gender"] == "Male", :]
female_purchase = merged_data_df.loc[merged_data_df["Gender"] == "Female",:]
non_specific_purchase = merged_data_df.loc[merged_data_df["Gender"] == "Other / Non-Disclosed",:]

#Purchase Count

male_purchase_count = male_purchase["Item ID"].count()
female_purchase_count = female_purchase["Item ID"].count()
non_specific_purchase_count = non_specific_purchase["Item ID"].count()

#Average Purchase Price

male_average_price = round(male_purchase["Price"].mean(),2)
female_purchase_price = round(female_purchase["Price"].mean(),2)
non_specific_purchase_price = round(non_specific_purchase["Price"].mean(),2)

#Total Purchase Value
male_total_purchase = round(male_purchase["Price"].sum(),2)
female_total_purchase = round(female_purchase["Price"].sum(),2)
non_specific_total_purchase = round(non_specific_purchase["Price"].sum(),2)

#Normalized Totals
male_normalized = male_total_purchase/male
female_normalized = female_total_purchase/female
non_specific_normalized = non_specific_total_purchase/non_gender

purchasing_analysis_df = pd.DataFrame({"Purchase Count":[male_purchase_count,female_purchase_count,non_specific_purchase_count],
                                       "Average Purchase Price":["$" + str(male_average_price),"$" + str(female_purchase_price),"$" + str(non_specific_purchase_price)],
                                       "Total Purchase value":["$" + str(male_total_purchase),"$"+ str(female_total_purchase),"$" + str(non_specific_total_purchase)],
                                       "Normalized Totals":["$" + str(male_normalized),"$" + str(female_normalized),non_specific_normalized]
                                    },index=["Male","Famale","Other/ Non-Disclosed"])

purchasing_analysis_df
# Out:
#                      Average Purchase Price Normalized Totals  Purchase Count  \
# Male                                  $2.94    $2.94479136691             695
# Famale                                $2.86    $2.85763513514             148
# Other/ Non-Disclosed                  $3.15             3.155              12
#
#                      Total Purchase value
# Male                             $2046.63
# Famale                            $422.93
# Other/ Non-Disclosed               $37.86

# %% [markdown]
# <h1 style="font-size:100;font-weight:600;">Age Demographics</h1>

# %%
age_group_names = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40-44","45-49"]
bins = [0,9,14,19,24,29,34,39,44,49]

merged_data_df_2 = merged_data_df
merged_data_df_2["Age Group"]=pd.cut(merged_data_df["Age"],bins,labels=age_group_names)
merged_data_df_2 = merged_data_df_2.groupby("Age Group")

age_count = merged_data_df_2["Age Group"].count()
age_total = merged_data_df["Age Group"].count()
age_percentage = age_count/age_total*100

age_demographics_df = pd.DataFrame({"Age Count":age_count,"Age Percentage": age_percentage})
age_demographics_df
# Out:
# /Users/yukun.peng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#            Age Count  Age Percentage
# Age Group
# 10-14             38        4.444444
# 15-19            144       16.842105
# 20-24            371       43.391813
# 25-29            133       15.555556
# 30-34             71        8.304094
# 35-39             48        5.614035
# 40-44             17        1.988304
# 45-49              1        0.116959
# <10               32        3.742690

# %%
#Age Analysis



age_purchase_count = merged_data_df_2["Item ID"].count()
age_average_purchase_price = merged_data_df_2["Price"].mean() 
age_total_purchase_value = merged_data_df_2["Price"].sum()
age_normalized_total = age_total_purchase_value/age_purchase_count

age_demographics_analysis = pd.DataFrame({"Purchase Count":age_purchase_count,
                             "Average Purchase Price":age_average_purchase_price,
                              "Total Purchase Value":age_total_purchase_value,
                              "Normalized Totals":age_normalized_total
                            })
age_demographics_analysis.head()
# Out:
#            Average Purchase Price  Normalized Totals  Purchase Count  \
# Age Group
# 10-14                    2.787105           2.787105              38
# 15-19                    2.894653           2.894653             144
# 20-24                    2.925687           2.925687             371
# 25-29                    2.970526           2.970526             133
# 30-34                    2.973803           2.973803              71
#
#            Total Purchase Value
# Age Group
# 10-14                    105.91
# 15-19                    416.83
# 20-24                   1085.43
# 25-29                    395.08
# 30-34                    211.14

# %%
top_SN = merged_data_df.groupby("SN").Price.agg(("count","sum","mean"))
top_SN.sort_values('sum',ascending=False,inplace = True)
top_SN.rename(columns={"count":"Purhcase Count","sum":"Total Purchase Value","mean":"Average Purchase Price"},inplace=True)
top_SN["Average Purchase Price"]="$" + (round(top_SN["Average Purchase Price"],2)).astype(str)
top_SN["Total Purchase Value"]="$" + (round(top_SN["Total Purchase Value"],2)).astype(str)
top_SN.iloc[0:5]
# Out:
#                Purhcase Count Total Purchase Value Average Purchase Price
# SN
# Undirrala66                 5               $17.06                  $3.41
# Aerithllora36               4                $15.1                  $3.78
# Saedue76                    4               $13.56                  $3.39
# Sondim43                    4               $13.02                  $3.26
# Mindimnya67                 4               $12.74                  $3.18

# %% [markdown]
# <h1>Most Popular Item</h1>

# %%
top_item = merged_data_df.groupby("Item Name").Price.agg(("count","sum"))
top_item.sort_values('count',ascending=False,inplace = True)
top_item.rename(columns={"count":"Purhcase Count","sum":"Total Purchase Value","mean":"Average Purchase Price"},inplace=True)
top_item.iloc[0:5]
# Out:
#                                       Purhcase Count  Total Purchase Value
# Item Name
# Final Critic                                      13                 37.24
# Stormcaller                                       12                 40.19
# Betrayal, Whisper of Grieving Widows              11                 25.85
# Arcane Gem                                        11                 27.11
# Trickster                                         10                 23.22

# %% [markdown]
# <h1>Most Profitable Item</h1>

# %%
top_profit_item = merged_data_df.groupby(["Item Name","Item ID","Price"]).Price.agg(("count"))
top_profit_item
# Out:
# Item Name                                 Item ID  Price
# Abyssal Shard                             162      2.04      3
# Aetherius, Boon of the Blessed            137      4.75      4
# Agatha                                    120      1.91      5
# Alpha                                     130      1.56      7
# Alpha, Oath of Zeal                       79       1.31      1
#                                                    2.88      7
# Alpha, Reach of Ending Hope               47       1.55      6
# Amnesia                                   22       3.57      6
# Apocalyptic Battlescythe                  93       3.91      4
#                                                    4.49      2
# Arcane Gem                                84       2.23     10
#                                                    4.81      1
# Avenger                                   102      4.16      6
# Azurewrath                                160      2.22      5
# ...

# %%
top_profit_item.sort_values('count',ascending=False,inplace = True)
top_profit_item.rename(columns={"count":"Purhcase Count","sum":"Total Purchase Value","mean":"Average Purchase Price"},inplace=True)
top_profit_item.iloc[0:5]
# Out:
#      Age  Gender  Item ID                                  Item Name  Price  \
# 0     38    Male      165                Bone Crushing Silver Skewer   3.37
# 1     21    Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2     34    Male      174                            Primitive Blade   2.46
# 3     21    Male       92                               Final Critic   1.36
# 4     23    Male       63                             Stormfury Mace   1.27
# 5     20    Male       10                                Sleepwalker   1.73
# 6     20    Male      153                            Mercenary Sabre   4.57
# 7     29  Female      169     Interrogator, Blood Blade of the Queen   3.32
# 8     25    Male      118           Ghost Reaver, Longsword of Magic   2.77
# 9     31    Male       99       Expiration, Warscythe Of Lost Worlds   4.53
# 10    24    Male       57            Despair, Favor of Due Diligence   3.81
# ...
